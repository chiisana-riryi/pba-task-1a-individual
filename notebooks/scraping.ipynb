# %%
from google_play_scraper import reviews, Sort
from pprint import pprint
import pathlib
import csv
from utils import *
from nltk.corpus import stopwords

# %%
def scrape_reviews(
        count : int = 100,
        score : int = None,
        sort  : Sort = Sort.MOST_RELEVANT, 
        lang  : str = "en",
    ) -> Tuple[List[dict], _ContinuationToken]:

    return reviews(
        app_id = app_id,
        lang   = lang,
        sort   = sort,
        count  = count,
        filter_score_with  = score,
    )

# %%
# test
data, _ = scrape_reviews(count=1)

pprint(data)
# Out:
# [{'appVersion': '3.10.9',
#   'at': datetime.datetime(2026, 3, 11, 0, 7, 34),
#   'content': 'The Steam app is a great way to interact with friends and access '
#              'your steam account through mobile instead of using the web '
#              'browser and(or) Desktop version. It is a little slower then the '
#              "desktop version and slightly clunky. However it's great for just "
#              'accessing your account, updating information and chatting with '
#              'friends. If you have two-way authentication enabled then you '
#              'might get a authentication loop until you disable it or delete '
#              'steam chat then reinstall it(it worked for me).',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.9',
#   'reviewId': 'fde4f8c6-06c5-4d58-b5d8-2f12540509b6',
#   'score': 5,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL9VqVr2hIjb440ObhStkEVgxhJMwtWkOzDmJW4TVw5IXMVKw=mo',
#   'userName': 'James Jenkins'}]

# %%
# scrape and store to csv
data, _ = scrape_reviews(count=scrape_review_count)

# make content lowercase

for review in data:
    if (review["content"] == None):
        continue
    
    content_lowercase = review["content"].lower()

    review["content"] = content_lowercase

# mkdir the parent if not exists
dir_parent = pathlib.Path(reviews_csv_file_template).parent
dir_parent.mkdir(parents=True, exist_ok=True)

reviews_csv_file_dir_star = reviews_csv_file_template.format("mixed")
reviews_csv_file = open(reviews_csv_file_dir_star, "w")

# write list of dicts as a csv into file
output_csv(data=data, file=reviews_csv_file)

# close file
reviews_csv_file.close()
