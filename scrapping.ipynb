# %%
import google_play_scraper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import google_play_scrapper
#
# File ~/Documents/School/Semester 6/PBA/pba-task-1a-individual/.env/lib/python3.14/site-packages/google_play_scrapper/__init__.py:1
# ----> 1 from .constants.google_play import Sort  # noqa: F401
#       2 from .features.app import app  # noqa: F401
#       3 from .features.permissions import permissions  # noqa: F401
#
# ModuleNotFoundError: No module named 'google_play_scrapper.constants'
