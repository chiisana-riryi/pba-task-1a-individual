# %% [markdown]
# ## 1. Import Libs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
import csv
from wordcloud import WordCloud

nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/lenovo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/lenovo/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lenovo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 2. Import Preprocessed Data

# %%
path = "../preprocessed/reviews-mixed-stars.csv"
with open(path, newline="") as f:
    reader = csv.DictReader(f)
    data = list(reader)

data_df = pd.DataFrame(data)

# convert dates to datetime
data_df['at'] = pd.to_datetime(data_df['at'])

data_df.head()
# Out:
#                                reviewId       userName  \
# 0  fde4f8c6-06c5-4d58-b5d8-2f12540509b6  A Google user
# 1  04c5e4af-4def-4458-a54b-9e8b825c77f6  A Google user
# 2  b030ed42-5b10-4929-b8b3-ec7ac7233b67  A Google user
# 3  c2e5379e-089d-49a7-9b12-a2911d8177d9  A Google user
# 4  6a993a5e-b43e-415a-8fc0-c8295ef0410d  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content score thumbsUpCount  \
# 0  steam app great way interact friends access st...     5             6
# 1  app website great customer support entirely un...     2             3
# 2  bare minimum necessarily bad sense app essenti...     3             0
# ...

# %% [markdown]
# # 3. Yearly Data Overview

# %%
data_df['review_date'] = data_df['at'].dt.to_period('Y')
review_trend = data_df.groupby('review_date').size()

review_trend.plot(kind="bar", figsize=(12, 6))
plt.title("Yearly Review Counts Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.grid(True)
plt.show()

# %%
data_df['review_date'] = data_df['at'].dt.to_period('Y')
review_trend = data_df.groupby(['review_date', 'score']).size().unstack(fill_value=0)

review_trend.plot(kind="bar", figsize=(12, 6))
plt.title("Yearly Review Counts by Score")
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.grid(True)
plt.show()
