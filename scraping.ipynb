# %%
from google_play_scraper import reviews, Sort
from pprint import pprint

# %%
app_id : str = "com.valvesoftware.android.steam.community"

# %%
def scrape_reviews(
        score : int = None,
        sort  : Sort = Sort.MOST_RELEVANT, 
        lang  : str = "en",
        count : int = 100
    ) -> Tuple[List[dict], _ContinuationToken]:

    return reviews(
        app_id = app_id,
        lang   = lang,
        sort   = sort,
        count  = count,
        filter_score_with  = score,
    )

# %%
result, _ = scrape_reviews()

pprint(result)
# Out:
# [{'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 24, 7, 43, 53),
#   'content': 'Great until it stops working. Every once in awhile I am "logged '
#              'in" but I have to relog in. Then I cannot due to a server issue. '
#              "The website doesn't have this issue, but it does automatically "
#              'redirect to the broken application when I select something. '
#              'Steam Guard only compounds this problem. The desktop application '
#              'and the website seem to be much better platforms.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '1dd79e79-2398-4946-8081-bff5e9e50280',
#   'score': 3,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocImwGipvvCXAP_eWrNiZRqvvRuG3pk3IyYJGuCEItzr-WNL3A=mo',
#   'userName': 'Gideon'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 20, 7, 50, 24),
#   'content': "I've been trying for well over an hour to log into the app after "
#              'changing my password on my account. I continuously get the error '
#              "that it's a server issue and thus cannot log in. I'm frustrated "
#              'and confused, as I love to use steam. I had it on my phone to '
#              'share the games I play with my friends on the go, and now am '
#              'unable to. I feel this is a bug rather than the end all be all, '
#              "but I do hope it's fixed.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '008891c9-1f0f-43ec-a7b3-2e0c1816b93d',
#   'score': 1,
#   'thumbsUpCount': 216,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIGCfLNa1gIU9onxujrGoKHEsO_pRatL9vBhma_koooWbVQxA=mo',
#   'userName': 'Leo Rose'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 20, 7, 24, 5),
#   'content': 'it skips trailers after 3 seconds, really annoying any time '
#              "you're trying to watch a game's trailer. definitely prevented me "
#              "from buying some games recently. Also on the PC version, I've "
#              'been begging them for years to make it easier to browse our own '
#              "library. For over 10 years I've been asking and waiting. I get "
#              "that all the development went towards store pages, but it's like "
#              '4 clicks to see what genre a game even is from my library. '
#              "That's super tedious and feel horrible when you're in big pic",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': 'acb1fadb-5534-4843-b61a-08c23014090b',
#   'score': 2,
#   'thumbsUpCount': 23,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLWeAZ8Xlwt0W1SW2gYjEfppLlktNkcA5cWNqMHzkqETzQTFQu2=mo',
#   'userName': 'A Y'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 5, 21, 19, 55),
#   'content': "It's pretty damn hard to use this...website on mobile is easier "
#              'and more consistent. Wishlist is a great example - vertically '
#              'you can only view and not rearrange or change the order -- '
#              'horizontally you can tap in the number field as if to type a new '
#              'wishlist number order but no keys ever appear, and you can tap '
#              'and drag technically (like on desktop) but it is so difficult to '
#              'do correctly because the first time you drag it, the whole page '
#              'moves oddly, so you have to re-grab and get lucky.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '6a993a5e-b43e-415a-8fc0-c8295ef0410d',
#   'score': 2,
#   'thumbsUpCount': 16,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVWsb31fZWYd06ZhM5-VnaYD0BXk3WjMqe3yWZBJC3hEfZYu26pbQ',
#   'userName': 'Medigo Verus'},
#  {'appVersion': None,
#   'at': datetime.datetime(2026, 1, 21, 7, 39, 28),
#   'content': "Downloaded today and couldn't login. I have had the same "
#              'password for way too long, so even though I knew it was correct '
#              "I updated it. Still didn't work, so I double-checked my "
#              'username, yep it was right... I even went through the whole '
#              'process a third time to copy and paste from my notes app the '
#              'password to MAKE SURE I input it correctly and still nada. '
#              "Infuriating. I've tried to download this app a couple times over "
#              'the years and can never login.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '11a6bbe2-abad-48c2-a60a-eef4868fbdf0',
#   'score': 1,
#   'thumbsUpCount': 18,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVgK7orAMnz1-hhTXTYb_uc19SeyJBPlNp6q9804L_LIjIQeTQOOQ',
#   'userName': 'Squids'},
#  {'appVersion': '3.6.5',
#   'at': datetime.datetime(2023, 8, 23, 23, 23, 10),
#   'content': "If it works, it's good for doing Steam browsing & shopping. "
#              'However, as of yesterday, the app stops working entirely after '
#              'the first log-in, only reopening to a blank screen. This is an '
#              'issue that I have seen others report as well. If you download '
#              "it, never try to change your password or log out. While it won't "
#              "result in losing access to your steam account, you won't be able "
#              'to confirm any log-ins, trade offers, etc. unless you reinstall '
#              'the whole app & move your authenticator each time.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.6.5',
#   'reviewId': '0283b618-aa4d-4b82-abb3-5c48c3084f8d',
#   'score': 1,
#   'thumbsUpCount': 625,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXSD0FryeP19ZDkeTjltpDSVrdsLSz0hyOvBVUatTVhSbUnzm0',
#   'userName': 'Ranatöskr'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 10, 23, 23, 51, 31),
#   'content': 'In the old app, you could see friends online, and message them. '
#              'Now I need to use the inferior steam chat, a separate app? '
#              "That's annoying. Sure, the new UI is pretty, bit we haven't "
#              'gained any functionality, we lost some. Edit: the friends list '
#              'is just a little buried. If like for it to be available as a tab '
#              'at the bottom, as checking who is online is my most commonly '
#              'used function when using this app.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': 'c4113edc-cbad-46c0-8580-df27a577ebf5',
#   'score': 3,
#   'thumbsUpCount': 183,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWuExRc6FI1bIMXcJHNMF206wQ5qufwdcFVATwObFiXObgoWcgs',
#   'userName': 'Bryson Carlton'},
#  {'appVersion': '3.7.2',
#   'at': datetime.datetime(2023, 12, 9, 7, 56, 51),
#   'content': "I never write reviews. But wow. I'm actually impressed by how "
#              'unusable this app is. Got stuck on the steam guard. Tried '
#              'inputting the code sent to my email, and it randomly puts them '
#              "into the box. Can't delete, can only try, helplessly to input in "
#              'the correct order. When it finally happens, it errors out and '
#              'you have to start from the previous screen anyways.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.2',
#   'reviewId': '1b9897f8-c4f0-49e7-b624-a4639c6d78a9',
#   'score': 1,
#   'thumbsUpCount': 578,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU6dlAyChGPo3re-p1sJ_ZkP19ktI63jnbTGc2WtYPvVKHszp6kVw',
#   'userName': 'Clay Mertz'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 10, 15, 6, 56, 28),
#   'content': "I didn't believe it was possible, but they actually made the app "
#              'worse with the latest update. Using the store is much slower and '
#              'more laggy compared to the previous version. Suddenly I have a '
#              'bunch of "notifications" just to bombard me with game sales. '
#              "Even if the game is on my wishlist, I don't need a notification "
#              'for every sale. Worst of all though, is the removable of the '
#              "friends list from the app. I don't care that I can't chat "
#              'anymore, but not being able to even see who is online is awful.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': '5f3f801b-842d-4bd2-ab57-0bca457a03cf',
#   'score': 1,
#   'thumbsUpCount': 301,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUhj16mc7DLMxjMkGeQ4bZqcZdaIJm4W_1qfOCjkRCMGpJOQlrg',
#   'userName': 'Alex Hoet'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2023, 12, 31, 11, 16, 41),
#   'content': 'App is nice to check out games when not at my desk, but I always '
#              'have issues, it seems. App taking forever load even with good '
#              'connection, half the screen being blocked by a Grey bar, tapping '
#              'on something multiple times before it opens, and a few other '
#              "issues. It's been this way for at least a year, so I have no "
#              'idea of or when these issues will be resolved. My internet speed '
#              "is fine to, so I can only assume it's the app.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': 'a0d65bcf-3dd3-4b76-831a-9906271adc86',
#   'score': 3,
#   'thumbsUpCount': 762,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXMouU4yBUWVCi7IClNiExZv6-VNP7u6GwfPM73hWdBCOIQm7M',
#   'userName': 'Pirate Piccolo'},
#  {'appVersion': '2.3.13',
#   'at': datetime.datetime(2021, 7, 7, 23, 41, 56),
#   'content': 'Works well in securing your account (provided you are only '
#              'attempting to do one account per smart phone, I ran into issues '
#              'trying to have 2 accounts on the same cell), as well as buying '
#              'games on the fly & receiving chat messages when not at your PC '
#              '(reading is another matter), but there are a number of issues '
#              'with the app that makes it better to stick to doing those tasks '
#              'on your PC. Trailers (on Store pages) do not correctly work in '
#              'full screen on this app, nor do listings of Discussions on their '
#              'boards (the individual Discussions load fine, but good luck '
#              "getting to them if you don't have a direct link in chat or a "
#              'notification of a reply to one of those threads). Chat sometimes '
#              'also has an issue where it will glitch violently while the other '
#              'person is typing, making it pretty much impossible to read what '
#              'has been said while they are still typing; at the very least, '
#              'you know they sent you a message, but you might have to go to '
#              'your PC to read/reply to it...',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.13',
#   'reviewId': '18ea2534-41f5-4d8f-a50a-d5ee84335ab7',
#   'score': 2,
#   'thumbsUpCount': 20,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWVC4ZSihs8rd1h9x4_66ItqAXigj_VO-vRTfm3PAGY5fgHdmw',
#   'userName': 'WonderGamer'},
#  {'appVersion': '3.9.1',
#   'at': datetime.datetime(2024, 8, 18, 8, 56, 8),
#   'content': 'While I love steam this on one of the **WORST** official mobile '
#              "ports of anything I've ever seen. It's like everything is "
#              'hidden. Once you pull up the keyboard by searching for a game. '
#              'There is no way to get rid of it. I was trying to add a game to '
#              'my cart. I figured it out but while trying I tried to add it '
#              "through the wishlist. In the wishlist there's a cart button next "
#              'to the game. It does NOTHING.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.1',
#   'reviewId': 'cc92faff-6656-4c63-807c-f84cf8316c2d',
#   'score': 2,
#   'thumbsUpCount': 279,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWoDZwAyFDkgNIuHrWL3Rhce-0irox3p81XUq7FEgLd6_xS1Yg',
#   'userName': 'Jai Game'},
#  {'appVersion': '3.7.0',
#   'at': datetime.datetime(2023, 11, 16, 13, 1, 12),
#   'content': 'They gutted and ruined their app and made it so you now have to '
#              'download 2 separate apps just to try to get the same '
#              'functionality that this one app used to do just fine. Except '
#              'neither app does any of the things as well as the old one did. '
#              'EDIT: Now, additionally, to make a purchase while already logged '
#              "in, it's asking me to log in again. I do so, and after jumping "
#              'through all of their 2FA hoops, it just asks me to log in again '
#              "in an endless loop. It also won't let me contact support.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.0',
#   'reviewId': '2cde91d1-e803-44df-94f8-e587096c4f49',
#   'score': 1,
#   'thumbsUpCount': 108,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW8ow5jWEViazOlsILn4JZ3wu65Dk090P9Yj2EoNGjqD533zruS',
#   'userName': 'ManfromtheRedRiver'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 11, 10, 1, 28, 32),
#   'content': 'Old app was just fine and worked exactly like the pc store '
#              "version. Now, its slow asf. The full webpages don't even "
#              'display. For example, ill go to a workshop page for a mod for a '
#              'game. The text is perfectly fine, but the images are half '
#              'unseeable and you cannot scroll the page left or right. Its '
#              'frustrating and not only that whenever i try to use the website '
#              'instead it autodirects me back to the app. If i wanna use the '
#              'desktop version, let me....',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': 'd12e46d2-4d30-40f1-a5f0-fd7b9b6a39d8',
#   'score': 1,
#   'thumbsUpCount': 213,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX5HJRdhJt5MX6oDJ14o4qd9uZ4zqXieXQXY7gNC0LWf5Z_lD1Z',
#   'userName': 'Nathan Van Slyke'},
#  {'appVersion': '2.3.12',
#   'at': datetime.datetime(2021, 5, 3, 23, 58, 4),
#   'content': "It's Steam on the phone, and that's pretty cool. Easy access to "
#              'your library, friends, Steam Store, and while you obviously '
#              "can't play your PC games from your phone, having access to all "
#              'of this is great. The only thing that would make this app better '
#              'is if it was made more to fit a mobile atmosphere. While the '
#              "layout works fine, it's sharp edges make it feel occasionally "
#              'akward to press things.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.12',
#   'reviewId': 'd26b37a4-f6cd-4a42-b3c3-0c8650301850',
#   'score': 4,
#   'thumbsUpCount': 503,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW7T49xq3_bIphJLu9OwFmQGFbxy70UNXZYSg0RMoM9T7PmWqS9',
#   'userName': 'Tyler Sampson'},
#  {'appVersion': '3.9.6',
#   'at': datetime.datetime(2025, 1, 17, 6, 25, 4),
#   'content': "When it works, it's great. But it's even buggier than the old "
#              'Steam app. Nearly every time I open it, I have to manually kill '
#              "and restart Steam because it's in a bad state. They spent all "
#              'their effort on style, and cut every QA corner they possibly '
#              "could have. It's so bad I used Tasker to create a shortcut to "
#              'kill & relaunch Steam with one press. EDIT: more than 2 years '
#              'later... still true.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.6',
#   'reviewId': '3659cb00-8c38-411c-85d4-430d0008618f',
#   'score': 1,
#   'thumbsUpCount': 258,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW5vnLJDq70Z0x_nUfwllZ6e9S07lIN5_RBlSy4n33nYU-Bp3XC',
#   'userName': 'Dylan Horkin'},
#  {'appVersion': '3.6.5',
#   'at': datetime.datetime(2023, 8, 13, 1, 9, 5),
#   'content': 'If they could figure out the bugs this app would be alright. At '
#              'least 50% of the time I get an error rather than the link I '
#              'clicked on. I just had a notification for something on my wish '
#              'list on sale. I clicked on it and got "there was a problem '
#              'loading this web content." After that nothing worked. Other '
#              'times I get, "there was a problem signing you in."',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.6.5',
#   'reviewId': '236b359b-fcd0-48aa-8f72-67694722b04e',
#   'score': 2,
#   'thumbsUpCount': 163,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKn5WO55fk7YV70IdprfcI7niSKf_LNlm5evDmvig0oKmMLGw=mo',
#   'userName': 'David Cunningham'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2023, 12, 29, 1, 35, 11),
#   'content': "This is a joke, right? Everything about the app is worse. I've "
#              "been trying to give it a chance but you can't even maneuver "
#              'through the interface without in immense amount of redundancy. '
#              "It'll take 4-6 presses to get to the store homepage, and you'll "
#              'see the same page several times trying to get there. Horrible '
#              'experience. Constantly redirected off of discussion pages and '
#              "losing my text. My cart on the app and on desktop aren't synced "
#              'for some reason and the community market is awful.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': '00c0b40e-0644-4eba-89da-777b4428cbec',
#   'score': 1,
#   'thumbsUpCount': 850,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWPPm99IsdbNAnLwWQG0oRplJiqh3kPZu0b3KKs4g_Zkt8fWGEo',
#   'userName': 'J'},
#  {'appVersion': '2.3.13',
#   'at': datetime.datetime(2022, 7, 31, 10, 13, 51),
#   'content': 'This app is a complete waste of time. I would have NEVER '
#              "downloaded it if steam hadn't made it mandatory for me to sell "
#              'my inventory items on the marketplace. Setting it up took me '
#              "three days to do- because there's a bug where you input sms "
#              'codes for verification, however everytime I entered a code, it '
#              'gave me a #2 error code. Ended up getting my account locked, and '
#              "now I can't sell for two weeks. What a garbage, garbage app.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.13',
#   'reviewId': '916b8a9f-ab23-4532-a7f4-b53c0fbea176',
#   'score': 1,
#   'thumbsUpCount': 23,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX5XbuOCMlU9ro_2C210Se2vIYojhfYRl4ZTk-fg0-c4hoQhR8',
#   'userName': 'Penelope Deoliveira'},
#  {'appVersion': '3.9.1',
#   'at': datetime.datetime(2024, 10, 14, 21, 38, 35),
#   'content': 'This app bricked my account! 1000s of dollars in games gone. And '
#              "steam doesn't care. I can prove it's my account. But because of "
#              'their 2FA policy, forced down our throats, they refuse to give '
#              'me my games! This is a shining example of why you should NEVER '
#              'buy anything through steam. And why we need to bring back '
#              "physical game carts. Or else, it's only a matter of time until "
#              "you lose everything. If you can't hold it, you don't own it!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.1',
#   'reviewId': '07bfbbd8-a487-47a9-877b-61ac048fdb7d',
#   'score': 1,
#   'thumbsUpCount': 20,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLNCQf6FSwGFmZajuuwJWYytsTGwEqef0-nrx4WsMlJ_uczyA=mo',
#   'userName': 'Matt'},
#  {'appVersion': '3.9.0',
#   'at': datetime.datetime(2024, 6, 28, 15, 43, 38),
#   'content': 'Hey, I just downloaded Steam and ran into some issues while '
#              'trying to create an account. I kept getting stuck in a loop of '
#              'email verification, and despite verifying it several times, it '
#              'only recognized the email as already in use twice. This has '
#              "prevented me from creating a username and password. Maybe I'm "
#              "doing something wrong but whatever I'm doing just isn't working.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.0',
#   'reviewId': '4ad8b819-dafd-4c01-a90b-bbb9f801b2a4',
#   'score': 1,
#   'thumbsUpCount': 1162,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJcrtB8R9WkhJSUvb_wCKM8k3Q0GJIg8_od_nDuBDPF2GPv9w=mo',
#   'userName': 'Tianna Jones'},
#  {'appVersion': '3.1',
#   'at': datetime.datetime(2022, 12, 6, 19, 42, 56),
#   'content': 'Terrible update. I refuse to have two apps for one platform. '
#              'Searching games in one and chatting in the other.. if either app '
#              'actually worked properly. I am really disappointed and removing '
#              'Steam mobile altogether. Things can wait until I get home to my '
#              'pc. They ruined a familiar, easy to use, fully functional, '
#              'all-in-one app that we all once loved.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.1',
#   'reviewId': 'b1be3984-bd1e-4fb4-a2d6-94d21e4745a5',
#   'score': 1,
#   'thumbsUpCount': 17,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX6rA4qDkXhw0Bq08r2kyoQ55G9meTZp4c5rnX0T-r2-lYHnA_U',
#   'userName': 'Eddie Olson'},
#  {'appVersion': '2.3.7',
#   'at': datetime.datetime(2019, 1, 12, 3, 36, 17),
#   'content': 'glad to see a lot of the full client features have been added to '
#              'the mobile version. including tags, [purchased, ignored, and '
#              'wish listed marks when looking at items in the store without '
#              'having to open the item page], ability to redeam steam monetary '
#              'cards without having to go to the webpage to redeem [has to be '
#              'done through account settings]. it has been a while since I '
#              'updated my review.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.7',
#   'reviewId': '88f0f79c-870b-425d-8487-474ea1ab5ad7',
#   'score': 4,
#   'thumbsUpCount': 89,
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'userName': 'A Google user'},
#  {'appVersion': '3.5',
#   'at': datetime.datetime(2023, 3, 29, 0, 37, 10),
#   'content': 'Mostly unusable for anything but browsing new games from the '
#              "home screen. Search is missing for anything but games (can't "
#              'search workshop etc), back button is broken and throws you to '
#              'the home page no matter where you are on the site, several '
#              "features like friends are gone... honestly it's more hassle than "
#              "it's worth most of the time. It resembles the website, but "
#              "doesn't come even remotely close to what you can do on the web.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.5',
#   'reviewId': '4276d63c-cc2d-4bc9-b064-ed24ab2b56d2',
#   'score': 2,
#   'thumbsUpCount': 395,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWpwTpg2Idb2LsNWxa8CKfbhcofsRyyytVlKAWZIS2qiEV9TJKN',
#   'userName': 'Brad Richardson'},
#  {'appVersion': '2.3.13',
#   'at': datetime.datetime(2022, 9, 27, 8, 0, 19),
#   'content': 'So far I like the app except for a couple of problems. 1. I '
#              "really wish you'd add the option to remove and hide games from "
#              'your library and not just on the PC version of the app. 2. I '
#              "wish you'd make it easier to also add the free games to your "
#              'library instead of having to go to the page for the game and tap '
#              '"add to library" and then go back to the store page and scroll '
#              'down to the bottom again just to add the next game every time. '
#              'If you added those features the app would be great imo.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.13',
#   'reviewId': 'a844f84d-e1fa-4a05-833e-3e5431376b4d',
#   'score': 4,
#   'thumbsUpCount': 84,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL0NhpQZejQz1c7HGn1MuBQi2NBAa77pHZgP3cfDRZcalaRd9o=mo',
#   'userName': 'Katie M'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2023, 12, 26, 7, 17, 30),
#   'content': 'If you say and claim fixing any login issues then your lying. I '
#              'experience them both on the mobile and PC apps. On the mobile '
#              'app it does an infinite and repeating "email verified" yet it '
#              "doesn't work(This is for account creation) because it just "
#              'resets account creation. On the PC, Captcha glitches and says it '
#              "doesn't work and that's been an issue for years. I hate that "
#              'these bugs seem to pile up ontop of one other, and I am not able '
#              'to make an account whatever way possible. Please fix these.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': '0cc22f88-d35d-4f47-a86e-4ecece234ed6',
#   'score': 1,
#   'thumbsUpCount': 96,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUzAL3xQg6muc-_3mP7G7NHp9INAfgmT8bqGMvqOTKJhlvnVLU',
#   'userName': 'Dter Jext (Anoytmous)'},
#  {'appVersion': None,
#   'at': datetime.datetime(2024, 11, 4, 3, 28, 55),
#   'content': 'App only sorta works. You can mostly navigate it, its decent if '
#              'you want notifications for your wishlisted games going on sale, '
#              'but god forbid you try buying them on the app. It just will not '
#              'let you, it starts an endless cycle of making you reenter your '
#              'login credentials, verify the code from your email, rinse and '
#              'repeat with no end. Its like they dont want me to give them '
#              'money. And good luck navigating this godforsaken app, the cart '
#              'is nowhere to be found, and every function is hidden.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '12a80e4c-6a2f-422e-babb-fe00bf64fd37',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjURtemIX_WYfE97aLtOnIhCxXGPx9hjCWPUpsc6X0pflSbAw_w',
#   'userName': 'Crystal Waters'},
#  {'appVersion': '3.6.3',
#   'at': datetime.datetime(2023, 7, 4, 23, 37, 56),
#   'content': 'Updating my review from a 2 star to a 1 star. The app is truly '
#              'awful. As well as being a general buggy mess when browsing, it '
#              'failed when I ordered my Steam Deck causing a stuck pending '
#              'transaction for £349 that I had to call the bank to clear. I '
#              'also tried to buy games (forgetting my previous ordeal). The '
#              'same thing happened again. Steam told me "the 3D authentication '
#              'process has failed" and that is true - because the app failed. I '
#              'am now out of pocket with no options but to wait and hope.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.6.3',
#   'reviewId': '2e56b14a-493a-4c51-8601-ca72973f2190',
#   'score': 1,
#   'thumbsUpCount': 71,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUbQJsZVhUio0NZTUYgsVUdasRaeLMevDLJpsGZA9QGlLtYOF0RmA',
#   'userName': 'Sye Christian'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2023, 12, 26, 9, 23, 27),
#   'content': 'Tried to purchase a game through the app using PayPal and it '
#              'would just constantly fail to even login. Just open an external '
#              'browser window instead of trying to open everything in the app. '
#              'The in-app browser is terrible and fails most of the time when '
#              'attempting to intercept links to games on Steam. More often than '
#              "not it gets stuck on one and won't open any others without being "
#              'completely closing the app and trying again. Just use an '
#              'external browser so that things can actually work. Thanks.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': '0caaedca-72c6-4cde-8a64-cc639aef1c90',
#   'score': 1,
#   'thumbsUpCount': 144,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVDKLX78LbvbYkOYYYKjWYbgiFYEAYgVIEGkNAPCXwDOQeBJ923',
#   'userName': 'Todd Turner'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2024, 3, 1, 21, 21, 14),
#   'content': 'When I tried creating an account, I couldnt create a password. '
#              'Every time I tried, It would take me to the sign in page '
#              'although I didnt have an account. None of the help options would '
#              'make things any easier, if not make things worse. The account '
#              'recovery is just as difficult. After thirty minutes, it wouldnt '
#              'send the recovery email, and after I tried again, I had used all '
#              'the recovery attempts and my account name was apparently '
#              'invalid.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': '958430ba-035f-4383-917f-6e7e13115f23',
#   'score': 2,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVm1KzFY-P71QL7pVDHjtejEACDuUlLOZbwiTbJK4ds9d75MF0X',
#   'userName': 'Shantel Walker'},
#  {'appVersion': '3.9.0',
#   'at': datetime.datetime(2024, 7, 6, 23, 6, 17),
#   'content': 'Will NOT open, no matter how long I let it try to. The moment I '
#              'click on the icon, I get stuck on a grey loading screen with the '
#              'text "loading parental settings" in tiny black letters (i have '
#              'no parental settings enabled." I was able to use the app a small '
#              'handful of times before this issue began, and I remember it '
#              'being a cumbersome and frustrating expierence. All my trades are '
#              'forced to be delayed because I "haven\'t acessed the app in a '
#              'week," despite the fact I CANNOT access it.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.0',
#   'reviewId': 'c231602c-6299-4d77-a958-e9a5e4a812fe',
#   'score': 1,
#   'thumbsUpCount': 1145,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVH2w4m7uP2ecaeo7-Lvi79u6kQvnA5mcloI-xRecjkzbeoZRjq',
#   'userName': 'Ray Belloso'},
#  {'appVersion': '3.6.3',
#   'at': datetime.datetime(2023, 7, 4, 21, 56, 52),
#   'content': 'App is broken. It is clear that Steam wants to sell Steam Decks, '
#              'which is fine, but they seem to have abandoned the app in the '
#              'process. When it is a chore just to find a way to go back to '
#              'what you were previously viewing, and it says that the PayPal '
#              'you have used for purchases for YEARS no longer is valid, even '
#              'when I reset it, then there is a problem',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.6.3',
#   'reviewId': '52649099-d651-4df5-9404-e47083a555ba',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVdk62xrQY4EMbQ_F4Bd2HTb-eqYKsnfP28-zZUvPbfpJh1Pwq3',
#   'userName': 'Ciro Festa'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 10, 18, 10, 22, 51),
#   'content': 'Used to work well. I could get my authenticator code either as a '
#              'notification or through a widget. Now I would be forced to open '
#              'the app and use a qr code (not happening). Or select the option '
#              "to use the old code system. But wait, the code option doesn't "
#              'work. Instead it tries to make you approve or deny the request '
#              'based upon your IP location. TLDR: logging into desktop is a '
#              "nightmare and you can't log out of app.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': '78f8d84b-3eee-4a85-88fb-adff1ca3f3bc',
#   'score': 1,
#   'thumbsUpCount': 17,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWYAjO_wnVnC0WUR94sGzzgrY2ddkXnwXS_dDKsoWzeV8are59k',
#   'userName': 'S R'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 11, 17, 0, 47, 14),
#   'content': 'It took me 20 mins to send a simple message to a friend because '
#              'of the new lay out. The friends list is buried and when I do '
#              'finally get to the messages, it loads a completely different tab '
#              "and then it's so squished I can't type or click. Why fix "
#              "something if it isn't broken? I was excited to switch from Xbox "
#              'but this is just getting to be too much of a hassle.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': '353c3c58-abde-4ae4-ac18-05656ac46eed',
#   'score': 1,
#   'thumbsUpCount': 26,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXVQlnrE1eqAZ-JEAznKAnUHxeLGTUdU3eXFQM9S5KnHNgXxmEh',
#   'userName': 'Victoria'},
#  {'appVersion': '3.5',
#   'at': datetime.datetime(2023, 5, 2, 16, 22, 28),
#   'content': 'Slowest app on Google Play. If you have even the most minor '
#              'interruption in your connection, becomes completely unusable. '
#              'Most of the app is just a browser for the Steam website, but '
#              "worse than a regular browser in every way. Doesn't even let you "
#              "chat, that's a separate app! It's easier, faster, and more "
#              'convenient to use the website. Steam requires you to install the '
#              'app for 2FA and marketplace stuff. Worst part of Steam hands '
#              'down. Absolutely miserable.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.5',
#   'reviewId': '02baab26-ce05-4b10-ace9-a9287daf9f42',
#   'score': 1,
#   'thumbsUpCount': 92,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKndToIb4hZegVHN1OTYdHUv39wjKBMUa8oJWXSXhaSAkPnJTY=mo',
#   'userName': 'Andrew Hills'},
#  {'appVersion': '2.3.11',
#   'at': datetime.datetime(2019, 11, 21, 13, 55, 30),
#   'content': 'It wants me to access a menu to verify a code to change my '
#              "password, but I can't access the menu without logging in, which "
#              "I can't do because I don't remember my password... Why can't I "
#              'just enter the code I see in the app like before??? How this '
#              'made it through testing is beyond me. This is critical '
#              'functionality. App is literally useless currently.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.11',
#   'reviewId': 'ab5dbb62-50eb-467a-bb99-f8a2c194ca6c',
#   'score': 1,
#   'thumbsUpCount': 16,
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'userName': 'A Google user'},
#  {'appVersion': '2.3.13',
#   'at': datetime.datetime(2022, 10, 6, 6, 8),
#   'content': "I have really wanted to play a few games that I've only seen on "
#              "steam. However, I've been trying to create an account for the "
#              'last hour through my PC and my phone. Nothing is working and I '
#              'cannot create an account. Captcha keeps saying my responses are '
#              'invalid. This is absolutely ridiculous. You have someone wanting '
#              "to pay for games and your site, servers, and software won't "
#              'allow them to create an account.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.3.13',
#   'reviewId': 'e1f90376-6149-4822-bd31-299bee19f7cf',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVWIDueItGWtweVfePQwbPiyiERwCqLbYfijEtpUUJtu_7GEq0',
#   'userName': 'Lance Brown'},
#  {'appVersion': '3.1',
#   'at': datetime.datetime(2022, 12, 3, 22, 42, 35),
#   'content': "I can't access my wishlist, I can't add anything to my wishlist "
#              "because it says I'm not signed in (I uninstalled the app, "
#              "reinstalled it, signed back in, and it still won't let me do "
#              "anything), tried to load my profile, doesn't work. Says there is "
#              'a server error, try to reload, says the same thing again. Idk '
#              'what happened, the app was just fine before and all of a sudden '
#              "it's just not allowing me to do anything with my account. Would "
#              "enjoy them rolling back the update cause it's unusable.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.1',
#   'reviewId': '770602f3-27b7-4311-886d-3f69b30af180',
#   'score': 1,
#   'thumbsUpCount': 38,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUOzhyv3tDpnsko9Sq-LyFhwSqahosyZBujxo6x3S2XNOv42UTA',
#   'userName': 'Larkin Cook'},
#  {'appVersion': '3.6.3',
#   'at': datetime.datetime(2023, 6, 27, 18, 51, 37),
#   'content': 'Trying to communicate with anyone in "support," is a byzantine '
#              'migraine. Dive the app update, the app has both gained a ton of '
#              'functionality, and lost it. I honestly thought I could rely on '
#              "the app, and the Steam Deck to manage my library, but they've "
#              "kinda made it impossible. I can't really do anything other than "
#              "spend money, and I can't leave feedback, or talk to anyone, or "
#              'accomplish anything I need to on my phone, or on the Steam Deck '
#              'with a Bluetooth keyboard and mouse.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.6.3',
#   'reviewId': '827a7817-066d-445d-987f-fe2acb9386ff',
#   'score': 1,
#   'thumbsUpCount': 179,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXx9DXO9FRpN2g9KGECft8cnTIYrkzNd5W_7znPkKq25dSL-pvd',
#   'userName': 'Tinker Gnomad'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 10, 21, 8, 15, 2),
#   'content': 'Installed after the new update and instantly regretted it. The '
#              "only reason I'm still trying to bend it to my will is the app "
#              'spares me the seemingly daily verification of login dance that I '
#              'get with Chrome mobile. Half the time, links to Steam (e.g. to a '
#              "game's store page) are not resolved correctly and you're just "
#              "taken to a default page (Store main usually). I can't do "
#              'something as simple as see my own recent gaming activity. Some '
#              "of the menu items in the account overview view also don't work",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': 'e8384f9f-265c-4463-8aed-deef58b11a62',
#   'score': 1,
#   'thumbsUpCount': 8,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVf9ZFxWPuNhMamjdDcxTP-25OxjpwDxZPVWZsE-VwCqb1bPuGuoA',
#   'userName': 'Adam M'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 10, 26, 23, 10, 40),
#   'content': 'They stripped out functionality for seemingly no reason. '
#              'Previously you could do pretty much anything you wanted in this '
#              'app. Browse store, buy stuff, talk with friends, etc. Now they '
#              'have gotten rid of the ability to chat with friends (you need a '
#              'separate app for that), and they got rid of rid of the nice '
#              'mobile authentication widget. Thanks for making your app much, '
#              'much worse you dirty heathens.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': '312758eb-57e0-4afd-a932-2466d02bcd80',
#   'score': 1,
#   'thumbsUpCount': 67,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWvqFcz-8lNT36sUuncxhb1oqgB2XCUOprAkSfnTjByBfNgBddxtw',
#   'userName': 'Possum'},
#  {'appVersion': '3.0',
#   'at': datetime.datetime(2022, 11, 27, 5, 47, 33),
#   'content': "Poorly designed UI, extremely slow/laggy, won't load my Library. "
#              "The old app worked fine. They took what wasn't broken and "
#              '"fixed" it, and the result is as bad as you might expect. Just '
#              "give us the old app back. Edit: It's currently the Black "
#              'Friday/"Autumn" Sale and the app\'s store page won\'t load, just '
#              'keeps saying "There was a problem loading this web content" with '
#              'no solution I can find. This app is literally making me less '
#              "likely to spend money on Steam because I'm simply unable to.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.0',
#   'reviewId': '2c142a2e-f998-4f7d-99c1-ecb6fec4966b',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLhmkmRud_Z9SEEW7TT4RmUEQuNBnSzounUP9ISqAtbRppJjw=mo',
#   'userName': 'Jordan Sedley'},
#  {'appVersion': '3.5',
#   'at': datetime.datetime(2023, 4, 3, 21, 16, 39),
#   'content': 'When booting up my PC today, the Steam app asked for my user ID '
#              "& password (something I haven't had to to enter in YEARS). "
#              'Obviously can\'t remember, so clicked the "Help, I can\'t sign '
#              'in" link. It told me to open the steam app on my phone, and scan '
#              'a QR code. So I open the steam app on my phone, and it asks for '
#              'my user ID & password. There is literally no way to get around '
#              'it!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.5',
#   'reviewId': '32964060-58cb-42c1-be3a-a68823fbf464',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWilDEWfotbsK1EP9qiCfBxrZtwWuRcg3q-zkKD7GUWxiQCKtRJ',
#   'userName': 'Bill Young'},
#  {'appVersion': '3.9.1',
#   'at': datetime.datetime(2024, 9, 20, 2, 4, 8),
#   'content': 'It is quite literally impossible to create an account! I need to '
#              'input my email, and then confirm my email, but when I confirm my '
#              "email, I'm taken to the sign in screen, in which I don't have an "
#              'account to sign in with! Trying to create an account online is '
#              'also impossible, as no matter how you do the captha, it always '
#              'fails me! This is such an incredible waste of time.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.9.1',
#   'reviewId': 'f48fe3bf-2525-4750-911e-ed5169f37700',
#   'score': 1,
#   'thumbsUpCount': 13,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVAcPFyg3_etw-IEGyGqTXNr-EmUbeaW5p3xEgF-z5g6g0tz0w',
#   'userName': 'Andrew'},
#  {'appVersion': '3.7.7',
#   'at': datetime.datetime(2024, 5, 17, 4, 11, 53),
#   'content': "Just doesn't work sometimes. Presently can't set it as my 2 "
#              'factor, it (from the app) tells me I need to install the app, '
#              'and sends me to the play store ostensibly to install... Itself, '
#              "which of course isn't an option from the play store. If I try to "
#              'click done, it just silently fails out. I eventually figured out '
#              'that there is a second place I had to go to set up the 2 factor, '
#              'which worked, but the ux was awful. Presumably this is because '
#              'most of the app is just a web browser.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.7',
#   'reviewId': '78ea4d12-60fa-4215-847c-f7d9582f1dfa',
#   'score': 3,
#   'thumbsUpCount': 145,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU-NWdnCZiGVMos6L4pIKnOxLZEpSL0-tEI3zI7LOhfDPvuHDNb',
#   'userName': 'Ben Newell'},
#  {'appVersion': '3.7.2',
#   'at': datetime.datetime(2024, 1, 22, 23, 37, 52),
#   'content': "I literally can't sign into my account on mobile anymore. It "
#              'keeps asking me to authenticate with a steamguard code, but when '
#              'I go to type it in the letters keep jumbling around and the '
#              "keyboard keeps dissapearing. I can't find anywhere to contact "
#              'steam support. The email listed on their site sends a response '
#              "back saying it's no longer monitored. None of the self help "
#              "questions fit my situation, and I can't find where to open a "
#              "ticket. Used to love steam, but now I can't even open it.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.2',
#   'reviewId': 'f2d4940c-0cac-4550-ac53-9409dcffebce',
#   'score': 1,
#   'thumbsUpCount': 33,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX9IFJh5GDachhimFu9w33P4E4K3sTZIZWQVVcej8iBc16M6DCu6g',
#   'userName': 'Karen paun'},
#  {'appVersion': '3.5',
#   'at': datetime.datetime(2023, 3, 20, 18, 56, 49),
#   'content': "Terrible, can't sign up on your website so I installed the app. "
#              "Get to your app to see only a sign up screen. I've authenticated "
#              "my email twice now, everything goes through but there's no way "
#              "to go past that point so I can't continue actually creating my "
#              "account for Steam. As of now I'm left with two attempts on the "
#              'same email, with no page I can manually get to, and no automatic '
#              "prompt system in place. About to try a third time but I'm pretty "
#              "sure we know how that's going to go",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.5',
#   'reviewId': '140b647a-cfba-4d84-a697-455a9354bf6c',
#   'score': 1,
#   'thumbsUpCount': 316,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKQjXdG_Jk0Kxk07DSMK9azaTIurOdZM_K9ptxwprj6fjYR=mo',
#   'userName': 'Mark Bud'},
#  {'appVersion': '3.7.3',
#   'at': datetime.datetime(2024, 8, 4, 9, 30, 38),
#   'content': 'I, over 2 years ago, had the same email verification issue on '
#              'account creation that people are still talking about recently in '
#              'the reviews. Contacting customer support in steam is impossible. '
#              'Trying to return a game is impossible. This is honestly one of '
#              "the worst run operations I've ever experienced. The only issue I "
#              "haven't had on my PC is buying and downloading video games.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.3',
#   'reviewId': '31645e9f-9a27-46a3-b823-d07dea6c6b0c',
#   'score': 1,
#   'thumbsUpCount': 21,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWfWvm0iTJzggwEZFcVjfny9qh64kIn7ZzOVEUJgoiin22LlZbXPQ',
#   'userName': 'Benjamin Campbell'},
#  {'appVersion': '3.7.7',
#   'at': datetime.datetime(2024, 5, 5, 0, 14, 22),
#   'content': "It's a garbage site with no support. Have been using it for "
#              "years and have never been happy with it. The website won't let "
#              'me log in, even after verifying my account and changing my '
#              'password, so it prompted me to download the app. Now Steam is on '
#              "my PC, my laptop, and my phone, and I can't log into any of "
#              'them. I get to their Captcha anti robot and get stuck in an '
#              'infinite loop of selecting pics of bicycles and busses. There is '
#              'no way to contact Steam support without already being logged in.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.7',
#   'reviewId': 'bcc13106-1209-4e28-bccb-1ee6d28ba572',
#   'score': 1,
#   'thumbsUpCount': 77,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ1ZZy2tvjXt5WyxXZfLXbk9kToFc_Dmdn1k5T31OTGd5AQIA=mo',
#   'userName': 'Lord Kilmaurs'},
#  {'appVersion': '3.7.0',
#   'at': datetime.datetime(2023, 10, 31, 11, 57, 10),
#   'content': "It's pretty bad. You actually cannot buy anything with PayPal on "
#              'the app and has been an issue for over a year now with no plans '
#              'to fix it. Then they removed all the chat functionality to '
#              "another app that doesn't actually work either, so this all's "
#              "only use is for Steam Guard. Don't even bother to browse games, "
#              "you can't buy 'em! Might as well just stick to your mobile's web "
#              'browser.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.7.0',
#   'reviewId': '6b9dae10-104b-40f1-9d9c-5a6eaa8090c1',
#   'score': 1,
#   'thumbsUpCount': 25,
# ...
#              "save an image you send to your phone. you'd have to send it to "
#              'your email, or send it to friends to save the image. despite '
#              'saying save/share your image.. Used to have an option to '
#              "download, and now you don't.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': 'df638a8b-c0ae-43d6-bdbc-a535f9bf1b0a',
#   'score': 4,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXdibB13gB3ldPGUdO8YP96LQkZBL58Zwg6ezJ1owOFffQDHJw',
#   'userName': 'Tristan Helton'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 31, 15, 17, 14),
#   'content': 'Literally the absolute best customer service in the world. My '
#              "account was glitching so I couldn't buy games and I tried a few "
#              'times and they responded within 30 minutes and the whole issue '
#              'was resolved within 1.5 hours and they refunded the games and '
#              'when I put in the wrong address it took my money but steam said '
#              'it was declined so my banking account was glitching and later it '
#              'was automatically refunded and I got the games. They basically '
#              'have one of the best safety nets out of any gaming servic',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': 'b46f5298-72f8-48a7-aebb-23a02bcbc3b8',
#   'score': 5,
#   'thumbsUpCount': 33,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVxkj66VQdkmz8o8CvthRWoaCLNtQ9yCH0PUfVVjruUEvTFOfrp',
#   'userName': 'Sean Bobb'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 1, 30, 4, 36, 17),
#   'content': 'the app is great, but i dont know if its just my steam app, as I '
#              'keep needing to sign in even though I did 50 times each time I '
#              'leave the app, and then I cant add the steam guard thing as when '
#              'I press the retry button, it just send me back to the steam '
#              'guard and it keeps repeating. im just trying to recover my '
#              'account for my PC since I dont wanna spend 21 pounds again just '
#              'for a game!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '7a606633-8f3c-4587-b21c-277e019a865b',
#   'score': 3,
#   'thumbsUpCount': 14,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXMxpXMkqaPm1u0G5jcg6W3t4ZpF6wHWoemwH8YCXCGAZLieiI',
#   'userName': 'Alessandro Bucataru'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 23, 20, 56, 41),
#   'content': "never did I spend this much time to create an account (haven't "
#              "even finished yet). why can't the account creation be as easy as "
#              "it is on every other app?? perhaps it's easier to delete the "
#              'steam app and instead do the whole procedure on the website. '
#              'awful experience smh. edit: delete the steam app and create an '
#              "account on the website. it's much easier. don't even know if "
#              'account creation works on the steam app.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': 'f9512fe5-2bc5-4280-8adb-15ddfdaf7a76',
#   'score': 1,
#   'thumbsUpCount': 16,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJjEOaUY7itTtbyXpO3c62XGIDohQkPMhd9QsJb-JqShGtcpw=mo',
#   'userName': 'Duy-Anh Le'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 27, 21, 29, 19),
#   'content': 'Downloaded Cities skylines 2. Played a bit.Came back after 2 '
#              "days, and it couldn't start the launcher.Tried the fixes (launch "
#              'as administrator, check files integrity, reinstalled, updates.) '
#              "Nothing helped, can't contact the developers due to keeping "
#              'turned around by the AI chat bot.Asked for a refund.And got '
#              'denied for playing longer than 2 hours.(at 2 hours 30ish '
#              'mins)Cuz of "policies." Wondering where the gamers\' policies '
#              'are that give them the right to be able to play a game they '
#              'payed for...',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': 'e70b248f-fe15-4780-bb52-6a2b1cd96f6b',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVq_4RHx7D10-OS0KzjqEmGxYEiRw7R4cZ_Z8H18Jxyrk1_fzy-',
#   'userName': 'Demien Tol'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 8, 20, 11, 53),
#   'content': 'This app barely works, 2.5 star rating is generous. If you click '
#              "a game in a category and you want to go back, too bad, there's "
#              'no back button. you have to press the home icon and get sent to '
#              'the front page, so you have to search for the category again. '
#              "Everything is drop down menus, so if you're new navigating is "
#              'just confusing. adult content is FULLY hidden, regardless of '
#              'preference settings. Most of the issues have existed for years '
#              "so i'm not holding my breath for it to be fixed.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': 'cddfcf4e-323e-40b1-81c4-f92951ca5444',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWJUEW9qU_7V1TP4z2boJeeyyTzovHHWjn-eHKLat4DSvR_W1Ca',
#   'userName': 'Cosmo Holmes (cosmodewit)'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 18, 2, 43, 58),
#   'content': "Changed my account's password because I didn't remembered what "
#              'was it, then, the app in my PC asked me to login again. Fine by '
#              "me, IF it wasn't for the lame app and site to not recognize my "
#              'new password or whatever it gone wrong. Tried to login A LOT OF '
#              'TIMES and still nothing happened. both apps said "there was an '
#              'issue to log you in. please try again later." or something like '
#              'that and nothing happened after that. Now how the hell am I '
#              'supposed to play anything without my account?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '5e3b6fde-76d8-4116-9c46-9107adecf0e7',
#   'score': 1,
#   'thumbsUpCount': 39,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWpjdhzYT4QAPUHN1xPb2Ph33reV9aBPPLH6vK5k_Q2f2A9fz2Y',
#   'userName': 'Giovani Barduzzi'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 21, 3, 21, 1),
#   'content': 'The chat function is really broken. You send a message, it gets '
#              'stuck and then if someone replies to you, your message '
#              'disappears without an option to reattempt sending it. I also get '
#              'notifications of messages received but when I open the app, '
#              "they're not there.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': 'db5ec390-07c5-4d93-8a12-a56648b0f5ce',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWdMK6vEYnbluMak3sv4tNE4h_yAEEx_hCJhX9bmoB_R6xoEZt_',
#   'userName': 'Sean Smith'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 1, 25, 1, 12, 14),
#   'content': 'Recent changes have made the app far less usable. The app now '
#              'ignores your settings for any form of "adult" content. now if '
#              'you want to see everything on your list of games with out '
#              'bluring, even non sexual in nature, you have to log in through '
#              'the browser. app is essentially just a authenticator at this '
#              'point.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '23d5257a-a03b-479a-9016-63fbc27bad30',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW6-Rq2BEpzzaFUAPcFapFhZwHxLz3EaxUBMRblO8ApGQi6RlSdVA',
#   'userName': 'Tim Sizemore'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 22, 1, 28, 17),
#   'content': 'Plagued with massive bugs that have sat unfixed for months or '
#              'even years. One is when you hit the back button on your phone, '
#              "it just closes the app. And the other is when you're watching a "
#              'trailer for a game on the store page, it interrupts the trailer '
#              'every few seconds to carousel to a picture. Really bad '
#              "experience, don't recommend.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '3c01468a-34c5-4bbe-9ba8-6af1450e3f13',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWUihbjXAola_Q-m05CRQIwLDCtTBQWV7fB5D8VMERuBzh1kx2b',
#   'userName': 'Ricky Keisling'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 17, 2, 47, 58),
#   'content': 'This app is incredibly bad. Super buggy and glitchy, using your '
#              'phones back button to try and go back to previous screens exits '
#              'you from the app. Searching for games and using the exact game '
#              'name will often only bring up DLC or soundtracks and not the '
#              'actual game no matter how you sort it. For games where you need '
#              "to say you are over 18 it'll let you into the page but as soon "
#              'as you try to look at bundles or anything else the app will kick '
#              'you and not let you reauthnticate.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '5cfd836c-af9a-495c-aa6b-273db430a985',
#   'score': 1,
#   'thumbsUpCount': 13,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWOojuacINeMcCfdo0Y7rdeKWNAngu5zuh1__XSyZ8jpaXj5zZ1',
#   'userName': 'Berry Kay'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 21, 21, 21, 10),
#   'content': 'basically trying to buy literally a few steam trading cards but '
#              'you need to confirm via the app (why in the world would i need '
#              'to confirm the purchase of something with less than a dollar '
#              'value??? a steam trading card of all things) but no matter how '
#              'many times you try to confirm it just says you didnt confirm '
#              'even though you did then it locks you from making the '
#              'purchase... when this is fixed will update to 5 stars... '
#              'apparently this has been goin on since before october btw...',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': 'a5543fc0-64f4-4c02-ac8e-358f0bb600c4',
#   'score': 1,
#   'thumbsUpCount': 22,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL9yN0p1NEaMSXaXweZjp8eS1PAxOK-JPiydhDSwFG6Tjt4DA=mo',
#   'userName': 'Jordon A. W. S.'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 22, 10, 55, 13),
#   'content': 'Works pretty decent for its purpose. Steam guard works pretty '
#              "much every time, but it doesn't send a notification for logins "
#              'without Steam guard (like approving a 3rd party app). Some '
#              'specific pages will open in a browser before immediately '
#              'redirecting back to the app, like the pages for the new '
#              'hardware, and some random menu buttons when navigating. '
#              'Horizontal carousels have a tendency to be anywhere between '
#              'sluggish to violently flipping through 20 items in a second.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '27598cff-873b-4f16-93bf-dabf82d713a5',
#   'score': 4,
#   'thumbsUpCount': 27,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXcH9_YqUnw1P3KiM-jHzO5oN8yB82mu0Gxk7qaHRY4XHYJlSofnQ',
#   'userName': 'Karl Ovrevik'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 25, 8, 27, 17),
#   'content': 'Launching the app, I can\'t escape the "add authenticator '
#              'screen". The top Google Play review is literally someone who has '
#              'been locked out of steam by using this feature. Steam Guard is '
#              "not secure. It's a way to permanently lose access to your steam "
#              'account. How incompetent.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '2eca7062-8ca5-4ad1-8cd8-6d7bd5337cba',
#   'score': 1,
#   'thumbsUpCount': 10,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVumMuGmgUxMObUSXWxqZQE5lC2aTO1gyDql4j-kPTWOMsbg5vE',
#   'userName': 'Anonymous User'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 21, 21, 50, 9),
#   'content': "Customer service is terrible. I can't get in touch with a "
#              'person. I got a game so I could play it with my son and for 2 '
#              'hours we were trying to find each other. username, location, '
#              'password, nothing worked. I tried to return the game and they '
#              'said no because I "played" for 2 hours.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': '0448fa85-4ca8-4a04-8ff4-4bcc8829afb5',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWu6rgbJKCKDoJCtg5tfHSoqvur32vodbvUai18PdWuFEfkIAnrcg',
#   'userName': 'Rebekah Connatser'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2025, 12, 27, 5, 11, 55),
#   'content': 'This app is for people who love having their time wasted '
#              'arbitrarily.Because valve decides to hide things that used to be '
#              'in plain sight behind a dozen drop down menus. you can also rest '
#              "assured that they won't update any resources.So you can actually "
#              "find the options that you're looking for in the app either.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '16990bdd-6970-4799-bd49-18fb3344b91f',
#   'score': 2,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLg00r4YzYhPAD-5VEcW1Xiz_fG8jyumyVBmjlxrfMMFTp1fg=mo',
#   'userName': 'ron johnson'},
#  {'appVersion': '3.10.7',
#   'at': datetime.datetime(2026, 2, 28, 19, 52),
#   'content': "Worst, it's hard to create an account! After I verified my "
#              'account from the email it didn\'t show a "create a password" '
#              'when I returned to continue creating my account! Please make '
#              'sure that creating an account is easier than harder.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.7',
#   'reviewId': 'fda27c36-206a-47c0-a1af-f3c21739411c',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWv50w10_ku1XWMUiezvGAJkKU0AzTj-n9JB_aRh0e3GKPykL0',
#   'userName': 'J,Carlz ReaL'},
#  {'appVersion': '3.10.6',
#   'at': datetime.datetime(2026, 1, 7, 7, 40, 59),
#   'content': 'Only slight wrinkle... in the Android App, unable to purchase '
#              'cart contents using PayPal (whilst I have MFA enabled); Steam '
#              "app keeps failing the authentication with 'something went wrong' "
#              'error message (suspect when, post id/password input instead of a '
#              "'success' token, the Steam app instead gets hit with my setup's "
#              "extra 'enter MFA code' now response instead). Workaround is to "
#              'dump the Android App & do cart purchases via a '
#              'web-browser/client-logon instead... hence dropping a star out to '
#              'zero!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.10.6',
#   'reviewId': '6ad88c60-cb54-4490-a2d0-ed3e84e5f171',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLMN_qVRW2aLaxAV1i0RiNRu8A_r5MWhMrDTNjwWnEmTNYruQ=mo',
#   'userName': 'Nik Barnett'}]
